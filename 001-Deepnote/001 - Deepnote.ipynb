# %% [markdown]
# # TP01 \- Deepnote Soto Ángel

# %% [markdown]
# ¿Quién soy?

# %% [markdown]
# Mi nombre es Angel Soto, tengo 43 años, nací en Caracas, Venezuela\. Migre hace más de 8 años de mi país con la intención de buscar nuevas oportunidades de empleo, mejores condiciones de vida de las que mi país podía ofrecerme\.

# %% [markdown]
# ¿Qué hago actualmente?

# %% [markdown]
# Lamentablemente, me encuentro en busca de empleo ya que en enero de este año, debido a una "reestructuración organizacional" fui desvinculado\. Mientras tanto, me mantengo realizando cursos de actualización Database, cursos autodidactas de IA y otras herramientas ya que el mercado actual lo requiere al menos para los perfiles actuales profesionales\.

# %% [markdown]
# ¿Qué expectativas tengo de la materia?

# %% [markdown]
# Busco adquirir conocimientos y herramientas que me permitan adaptarme a las necesidades del mercado laboral, a través del diseño de agentes de IA capaces de tomar decisiones en base a los datos que le sean suministrados\.

# %%
print("Mi segundo notebook en Deepnote")
# Out:
# Mi segundo notebook en Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=dc8fcfea-edbc-4dfa-be3c-a10ccc6e8f46' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
